# %%
import pandas as pd
data=pd.read_csv('Indian_Kids_Screen_Time.csv')
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data.dropna
# Out:
# <bound method DataFrame.dropna of       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
data['Health_Impacts'].unique()
# Out:
# array(['Poor Sleep, Eye Strain', 'Poor Sleep', nan, 'Poor Sleep, Anxiety',
#        'Poor Sleep, Obesity Risk', 'Eye Strain', 'Obesity Risk',
#        'Anxiety', 'Poor Sleep, Anxiety, Obesity Risk',
#        'Eye Strain, Obesity Risk', 'Eye Strain, Anxiety, Obesity Risk',
#        'Anxiety, Obesity Risk', 'Poor Sleep, Eye Strain, Obesity Risk',
#        'Poor Sleep, Eye Strain, Anxiety',
#        'Poor Sleep, Eye Strain, Anxiety, Obesity Risk',
#        'Eye Strain, Anxiety'], dtype=object)

# %%
data['Health_Impacts'] = data['Health_Impacts'].fillna('No Symptoms')

data.reset_index(drop=True)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data['Health_Impacts'] = data['Health_Impacts'].apply(lambda x: 1 if x == 'Poor Sleep' else 0 if x == 'No Symptoms' else 2)

# %%
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data['Age_Group'] = data['Age'].apply(lambda x: 0 if 8 <= x <= 13 else 1 if 14 <= x <= 18 else None)

# %%
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender'] = data['Gender'].map({'Male': 1, 'Female': 0})

# %%
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14       1                      3.99     Smartphone
# 1      11       0                      4.61         Laptop
# 2      18       0                      3.73             TV
# 3      15       0                      1.21         Laptop
# 4      12       0                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17       1                      3.26     Smartphone
# 9708   17       0                      4.43     Smartphone
# 9709   16       1                      5.62     Smartphone
# 9710   17       1                      5.60             TV
# 9711   15       0                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
data['Exceeded_Recommended_Limit'].unique()
# Out:
# array([ True, False])

# %%
data['Exceeded_Recommended_Limit'] = data['Exceeded_Recommended_Limit'].apply(lambda x: 1 if x else 0)
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14       1                      3.99     Smartphone
# 1      11       0                      4.61         Laptop
# 2      18       0                      3.73             TV
# 3      15       0                      1.21         Laptop
# 4      12       0                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17       1                      3.26     Smartphone
# 9708   17       0                      4.43     Smartphone
# 9709   16       1                      5.62     Smartphone
# 9710   17       1                      5.60             TV
# 9711   15       0                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                              1                               0.42
# 1                              1                               0.30
# ...

# %%
data.drop('Age',axis=1)
# Out:
#       Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0          1                      3.99     Smartphone
# 1          0                      4.61         Laptop
# 2          0                      3.73             TV
# 3          0                      1.21         Laptop
# 4          0                      5.89     Smartphone
# ...      ...                       ...            ...
# 9707       1                      3.26     Smartphone
# 9708       0                      4.43     Smartphone
# 9709       1                      5.62     Smartphone
# 9710       1                      5.60             TV
# 9711       0                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                              1                               0.42
# 1                              1                               0.30
# 2                              1                               0.32
# ...

# %%
data['Primary_Device'].unique()
# Out:
# array(['Smartphone', 'Laptop', 'TV', 'Tablet'], dtype=object)

# %%
data['Primary_Device'] = data['Primary_Device'].apply(lambda x: 1 if x == 'Laptop' else 0 if x == 'Smartphone' else 2 if x== 'TV' else 3 )
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0      14       1                      3.99               0
# 1      11       0                      4.61               1
# 2      18       0                      3.73               2
# 3      15       0                      1.21               1
# 4      12       0                      5.89               0
# ...   ...     ...                       ...             ...
# 9707   17       1                      3.26               0
# 9708   17       0                      4.43               0
# 9709   16       1                      5.62               0
# 9710   17       1                      5.60               2
# 9711   15       0                      6.12               2
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                              1                               0.42
# 1                              1                               0.30
# ...

# %%
data['Urban_or_Rural'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
data['Urban_or_Rural']=data['Urban_or_Rural'].map({'Urban':1,'Rural':0})
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0      14       1                      3.99               0
# 1      11       0                      4.61               1
# 2      18       0                      3.73               2
# 3      15       0                      1.21               1
# 4      12       0                      5.89               0
# ...   ...     ...                       ...             ...
# 9707   17       1                      3.26               0
# 9708   17       0                      4.43               0
# 9709   16       1                      5.62               0
# 9710   17       1                      5.60               2
# 9711   15       0                      6.12               2
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                              1                               0.42
# 1                              1                               0.30
# ...

# %%
data.drop('Age',axis=1)
# Out:
#       Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0          1                      3.99               0
# 1          0                      4.61               1
# 2          0                      3.73               2
# 3          0                      1.21               1
# 4          0                      5.89               0
# ...      ...                       ...             ...
# 9707       1                      3.26               0
# 9708       0                      4.43               0
# 9709       1                      5.62               0
# 9710       1                      5.60               2
# 9711       0                      6.12               2
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                              1                               0.42
# 1                              1                               0.30
# 2                              1                               0.32
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Features (all columns except 'Health_Impacts')
X = data.drop(columns=['Health_Impacts'])

# Target column
Y = data['Health_Impacts']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5542974781266083
# Confusion Matrix:
#  [[396  50 201]
#  [ 52  84 306]
#  [ 81 176 597]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.61      0.67       647
#            1       0.27      0.19      0.22       442
#            2       0.54      0.70      0.61       854
#
#     accuracy                           0.55      1943
#    macro avg       0.52      0.50      0.50      1943
# weighted avg       0.55      0.55      0.54      1943

# %%
new_data = [[12, 1, 4.5, 1, 1, 0.36, 2, 1]]  # List in the same order as X_train columns
prediction = model.predict(new_data)
print("Predicted Health Impact:", prediction[0])
# Out:
# Predicted Health Impact: 2
# C:\Users\priyn\anaconda3\envs\priyanshenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(model,'screentime.joblib')
# Out:
# ['screentime.joblib']
